# %%
import sys
import pandas as pd

print("Python 运行成功！")
print("Python 版本：", sys.version)
print("pandas 版本：", pd.__version__)
# Out:
# Python 运行成功！
# Python 版本： 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# pandas 版本： 2.3.3

# %%
# %pip install duckdb

# %%
import duckdb

result = duckdb.sql("""
    SELECT
        'DuckDB 和 SQL 运行成功！' AS message,
        1 + 1 AS test_result
""").df()

result
# Out:
#               message  test_result
# 0  DuckDB 和 SQL 运行成功！            2
